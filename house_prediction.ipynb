# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## load dataset

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    floors  waterfront  view  condition  ...  yr_built  yr_renovated  zipcode  \
# 0     1.0           0     0          3  ...      1955             0    98178
# 1     2.0           0     0          3  ...      1951          1991    98125
# 2     1.0           0     0          3  ...      1933             0    98028
# 3     1.0           0     0          5  ...      1965             0    98136
# 4     1.0           0     0          3  ...      1987             0    98074
#
# ...

# %% [markdown]
# ### drop id column (does not important)

# %%
df.drop('id',axis = 1,inplace = True)

# %%
df
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  floors  \
# 0      20141013T000000  221900.0         3       1.00         1180     1.0
# 1      20141209T000000  538000.0         3       2.25         2570     2.0
# 2      20150225T000000  180000.0         2       1.00          770     1.0
# 3      20141209T000000  604000.0         4       3.00         1960     1.0
# 4      20150218T000000  510000.0         3       2.00         1680     1.0
# ...                ...       ...       ...        ...          ...     ...
# 21608  20140521T000000  360000.0         3       2.50         1530     3.0
# 21609  20150223T000000  400000.0         4       2.50         2310     2.0
# 21610  20140623T000000  402101.0         2       0.75         1020     2.0
# 21611  20150116T000000  400000.0         3       2.50         1600     2.0
# 21612  20141015T000000  325000.0         2       0.75         1020     2.0
#
# ...

# %%
df.shape
# Out:
# (21613, 20)

# %%
# let is see the infromation about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  object
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  yr_built       21613 non-null  int64
#  11  yr_renovated   21613 non-null  int64
#  12  zipcode        21613 non-null  int64
#  13  lat            21613 non-null  float64
#  14  long           21613 non-null  float64
#  15  sqft_living15  21613 non-null  int64
#  16  sqft_lot15     21613 non-null  int64
# ...

# %%
# check null value
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# sqft_lot         0
# sqft_above       0
# sqft_basement    0
# dtype: int64

# %%
# let's check duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, floors, waterfront, view, condition, grade, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, sqft_lot, sqft_above, sqft_basement]
# Index: []

# %%
# let's check the format
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# sqft_lot           int64
# sqft_above         int64
# sqft_basement      int64
# dtype: object

# %% [markdown]
# ### you must handle the data type of the date column

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# sqft_lot                  int64
# sqft_above                int64
# sqft_basement             int64
# dtype: object

# %%
# let's split date into year , month
df['month'] = df['date'].apply(lambda  date:date.month)
df['year'] = df['date'].apply(lambda date :date.year)

# %%
# number of columns
df.columns.value_counts().sum()
# Out:
# 22

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0 2014-10-13  221900.0         3       1.00         1180     1.0           0
# 1 2014-12-09  538000.0         3       2.25         2570     2.0           0
# 2 2015-02-25  180000.0         2       1.00          770     1.0           0
# 3 2014-12-09  604000.0         4       3.00         1960     1.0           0
# 4 2015-02-18  510000.0         3       2.00         1680     1.0           0
#
#    view  condition  grade  ...  zipcode      lat     long  sqft_living15  \
# 0     0          3      7  ...    98178  47.5112 -122.257           1340
# 1     0          3      7  ...    98125  47.7210 -122.319           1690
# 2     0          3      6  ...    98028  47.7379 -122.233           2720
# 3     0          5      7  ...    98136  47.5208 -122.393           1360
# 4     0          3      8  ...    98074  47.6168 -122.045           1800
#
#    sqft_lot15  sqft_lot  sqft_above  sqft_basement  month  year
# ...

# %%
# let's show some statistics
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living        floors  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   5.401822e+05      3.370842      2.114757   2079.899736      1.494309
# std    3.673622e+05      0.930062      0.770163    918.440897      0.539989
# min    7.500000e+04      0.000000      0.000000    290.000000      1.000000
# 25%    3.219500e+05      3.000000      1.750000   1427.000000      1.000000
# 50%    4.500000e+05      3.000000      2.250000   1910.000000      1.500000
# 75%    6.450000e+05      4.000000      2.500000   2550.000000      2.000000
# max    7.700000e+06     33.000000      8.000000  13540.000000      3.500000
#
#          waterfront          view     condition         grade      yr_built  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       0.007542      0.234303      3.409430      7.656873   1971.005136
# ...

# %% [markdown]
# ## Data visualization

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'sqft_lot',
#        'sqft_above', 'sqft_basement', 'month', 'year'],
#       dtype='object')

# %%
sns.countplot(data = df , x ='grade')
plt.show()

# %%
sns.countplot(data = df , x ='bedrooms')
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
plt.figure(figsize = (10,8))
sns.countplot(data = df , x ='bathrooms')
plt.show()

# %% [markdown]
# ### from the above graph we conclude that :
# * most of houses have average level of constraction and design
# *  little houses have the poor and high quality of constraction

# %%
sns.countplot(data = df , x = 'grade' , hue ='condition')
# to move the legend(condition calor) to right side of the graph
plt.legend(loc ='upper right')
plt.show()

# %% [markdown]
# ### from above graph :
# * most of the house in middle condition and average level of constraction

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'sqft_lot',
#        'sqft_above', 'sqft_basement', 'month', 'year'],
#       dtype='object')

# %%
sns.countplot(data = df , x='view',hue = 'waterfront')
plt.show()

# %% [markdown]
# ### from above the graph :
# * most of houses does not have the view and waterfront

# %%
for col in df.iloc[:,[1,15,18,19]]:
    sns.distplot(df[col] , kde = True)
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### from the above graph :
# * all of them hva a right skewness

# %%
# show outlier
for col in df.iloc[:,[1,15,18,19]]:
    sns.boxplot(x =df[col])
    plt.show()

# %%
# feature like number of bedrooms and bathrooms
plt.figure(figsize =(10,8))
sns.boxplot(data = df,x = 'bedrooms' ,y ='price' )
plt.show()

# %%
plt.figure(figsize =(10,8))
sns.boxplot(data = df,x = 'bathrooms' ,y ='price' )
plt.show()

# %%
plt.figure(figsize =(20,20))
sns.heatmap(df.corr(),annot = True)
plt.show()

# %% [markdown]
# ### from heatmap:
# * the most distingushed feature is sqft_livine ,then grade,then sqft_above , sqft_living15

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'sqft_lot',
#        'sqft_above', 'sqft_basement', 'month', 'year'],
#       dtype='object')

# %%
sns.scatterplot(data = df , x='sqft_living' , y = 'price',hue = 'grade')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
sns.scatterplot(data = df , x='sqft_living' , y = 'price',hue = 'condition')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
sns.scatterplot(data = df , x='sqft_living' , y = 'price',hue = 'sqft_basement')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
sns.scatterplot(data = df , x='sqft_living' , y = 'price',hue = 'yr_built')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
df['yr_built'].min() , df['yr_built'].max()
# Out:
# (1900, 2015)

# %%
sns.scatterplot(data = df , x ='sqft_living15',y ='price', hue ='grade')
plt.show()

# %%
# data visualization price Vs months and years
fig = plt.figure(figsize =(16,5))
fig.add_subplot(1,2,1)
df.groupby('month').mean()['price'].plot()
fig.add_subplot(1,2,2)
df.groupby('year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ### split data

# %%
x =df['sqft_living']
y =df['price']

# %%
# split data
from sklearn.model_selection import train_test_split
x_train , x_test, y_train,y_test = train_test_split(x,y,test_size =0.3,random_state = 101)

# %%
x_train.shape , x_test.shape
# Out:
# ((15129,), (6484,))

# %% [markdown]
# ### scaling the data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_x_train = scaler.fit_transform(x_train.array.reshape(-1,1))
scaled_x_test = scaler.transform(x_test.array.reshape(-1, 1))

# %% [markdown]
# ## simple Linear Regression

# %%
# without scaling
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
# fit training data
reg.fit(x_train.array.reshape(-1, 1) , y_train)

# evaluate the parameter of the model(slop , intercept)
print(reg.intercept_)
print(reg.coef_)
# Out:
# -37516.185256539145
# [277.67758563]

# %%
# pridict 
y_pred = reg.predict(x_test.array.reshape(-1, 1))
# put them in dataframe
s_df = pd.DataFrame({'Actual': y_test ,'predicted': y_pred})
s_df.head()
# Out:
#          Actual      predicted
# 3834   349950.0  254045.279654
# 1348   450000.0  528946.089427
# 20366  635000.0  656677.778816
# 16617  355500.0  617802.916828
# 20925  246950.0  426205.382744

# %%
from sklearn.metrics import mean_squared_error
# calculate loss function using RMSE
print('RMSE : {:.2f}'.format(np.sqrt(mean_squared_error(y_test , y_pred))))
# Out:
# RMSE : 262320.61

# %%
print('Linear Regression Model :')
# calculate accuracy of trainig
print('train score  {:.2f}'.format(reg.score(x_train.array.reshape(-1,1),y_train)))
print('test score  {:.2f}'.format(reg.score(x_test.array.reshape(-1,1),y_test)))
# Out:
# Linear Regression Model :
# train score  0.48
# test score  0.51

# %% [markdown]
# ### LR using Scaling

# %%
regressor = LinearRegression()
# fit training data
regressor.fit(scaled_x_train , y_train)

# evaluate the parameter of the model(slop , intercept)
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 539738.8806927094
# [253565.78684657]

# %%
y_pred = regressor.predict(scaled_x_test)
# put them in dataframe
scaled_df = pd.DataFrame({'Actual': y_test ,'predicted': y_pred})
scaled_df.head()
# Out:
#          Actual      predicted
# 3834   349950.0  254045.279654
# 1348   450000.0  528946.089427
# 20366  635000.0  656677.778816
# 16617  355500.0  617802.916828
# 20925  246950.0  426205.382744

# %%
from sklearn.metrics import mean_squared_error
# calculate loss function using RMSE
print('RMSE : {:.2f}'.format(np.sqrt(mean_squared_error(y_test , y_pred))))
# Out:
# RMSE : 262320.61

# %%
print('Linear Regression Model :')
# calculate accuracy of trainig
print('train score  {:.2f}'.format(regressor.score(scaled_x_train,y_train)))
print('test score  {:.2f}'.format(regressor.score(scaled_x_test,y_test)))
# Out:
# Linear Regression Model :
# train score  0.48
# test score  0.51

# %% [markdown]
# #### scaling does not make any deffirent in the model accuracy

# %% [markdown]
# # Multiple LR

# %%
df = df.drop('date',axis =1)

# %%
x = df.drop('price',axis =1)
y = np.log(df['price'])

# %%
# split training and testing
x_train,x_test,y_train , y_test = train_test_split(x,y, test_size =0.3, random_state = 101)

# %%
reg = LinearRegression()
reg.fit(x_train ,y_train)
print(reg.intercept_)
print(reg.coef_)
# Out:
# -135.2170041118075
# [-1.41678584e-02  6.76026279e-02  9.72137108e-05  7.89757708e-02
#   3.65256437e-01  6.07190634e-02  6.54756079e-02  1.59472473e-01
#  -3.38983507e-03  3.77952337e-05 -6.59995556e-04  1.40572602e+00
#  -1.65721935e-01  9.99606070e-05 -2.08225468e-07  4.58213862e-07
#   4.03330993e-05  5.68806115e-05  2.42353617e-03  6.47270449e-02]

# %% [markdown]
# ### scaling data

# %%
# coef data frame
coef_df = pd.DataFrame(reg.coef_,index = df.drop('price',axis =1).columns,columns = ['coefficient'])
coef_df
# Out:
#                 coefficient
# bedrooms      -1.416786e-02
# bathrooms      6.760263e-02
# sqft_living    9.721371e-05
# floors         7.897577e-02
# waterfront     3.652564e-01
# view           6.071906e-02
# condition      6.547561e-02
# grade          1.594725e-01
# yr_built      -3.389835e-03
# yr_renovated   3.779523e-05
# zipcode       -6.599956e-04
# lat            1.405726e+00
# long          -1.657219e-01
# sqft_living15  9.996061e-05
# sqft_lot15    -2.082255e-07
# sqft_lot       4.582139e-07
# sqft_above     4.033310e-05
# sqft_basement  5.688061e-05
# month          2.423536e-03
# year           6.472704e-02

# %%
y_pred = reg.predict(x_test)
dff = pd.DataFrame({'actual': y_test ,'predicted':y_pred})
dff.head()
# Out:
#           actual  predicted
# 3834   12.765546  13.193976
# 1348   13.017003  13.315747
# 20366  13.361380  13.014744
# 16617  12.781281  12.655939
# 20925  12.416941  12.143208

# %%
# cost function 

print('RMSE :{:.2f}'.format(np.sqrt(mean_squared_error(y_test , y_pred))))
# Out:
# RMSE :0.25

# %%
print("Linear Regression: ")
print('train score:{:.2f}'.format(reg.score(x_train , y_train)))
print('test_score :{:.2f}'.format(reg.score(x_test ,y_test)))
# Out:
# Linear Regression:
# train score:0.77
# test_score :0.77

# %% [markdown]
# ### scaling data

# %%
scaler = StandardScaler()
scaled_x_train = scaler.fit_transform(x_train)
scaled_x_test = scaler.transform(x_test)

# %%
reg = LinearRegression()
reg.fit(scaled_x_train ,y_train)
print(reg.intercept_)
print(reg.coef_)
# Out:
# 13.048102775621397
# [-0.01285792  0.05205337  0.06598029  0.04265999  0.03186034  0.04682635
#   0.04236728  0.18655054 -0.09995872  0.01523885 -0.03534476  0.19422231
#  -0.02339505  0.06806553 -0.00571839  0.01975845  0.05386065  0.03598265
#   0.00755625  0.0302489 ]

# %%
scaled_coef_df = pd.DataFrame(reg.coef_,index = df.drop('price',axis =1).columns,columns = ['coefficient'])
scaled_coef_df
# Out:
#                coefficient
# bedrooms         -0.012858
# bathrooms         0.052053
# sqft_living       0.065980
# floors            0.042660
# waterfront        0.031860
# view              0.046826
# condition         0.042367
# grade             0.186551
# yr_built         -0.099959
# yr_renovated      0.015239
# zipcode          -0.035345
# lat               0.194222
# long             -0.023395
# sqft_living15     0.068066
# sqft_lot15       -0.005718
# sqft_lot          0.019758
# sqft_above        0.053861
# sqft_basement     0.035983
# month             0.007556
# year              0.030249

# %%
y_pred = reg.predict(scaled_x_test)
scaled_dff = pd.DataFrame({'actual': y_test ,'predicted':y_pred})
scaled_dff
# Out:
#           actual  predicted
# 3834   12.765546  13.193976
# 1348   13.017003  13.315747
# 20366  13.361380  13.014744
# 16617  12.781281  12.655939
# 20925  12.416941  12.143208
# ...          ...        ...
# 1398   13.049793  13.249011
# 3364   12.943237  12.753320
# 18958  12.884741  12.761411
# 17845  12.427214  12.377782
# 16335  14.115615  13.675357
#
# [6484 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error
# calculate loss function using RMSE
print('RMSE : {:.2f}'.format(np.sqrt(mean_squared_error(y_test , y_pred))))
# Out:
# RMSE : 0.25

# %%
print("Linear Regression: ")
print('train score:{:.2f}'.format(reg.score(scaled_x_train , y_train)))
print('test_score :{:.2f}'.format(reg.score(scaled_x_test ,y_test)))
# Out:
# Linear Regression:
# train score:0.77
# test_score :0.77

# %% [markdown]
# ### conclude that:
# * multiple LR is better than simple LR
# * scaling does not affect on the accurcy of the model
# * log transformation helps to increase the accuracy by (0.71 to 0.77)
